# %%
import py3Dmol
from IPython.display import display
from helix_drawer import calculate_helix_coordinates, parse_ancestry_dna, load_config, DNAConfig

# Initialize viewer with larger dimensions to accommodate legend
viewer = py3Dmol.view(width=1000, height=800)
display(viewer)

# Load data
config = load_config()
file_path = config['dna_file_path']
base_pairs = config.get('base_pairs', 200)
dna_data = parse_ancestry_dna(file_path)

# Add DNA structure for both strands
coords = calculate_helix_coordinates(base_pairs)
for i in range(base_pairs):
    # First strand
    viewer.addSphere({
        'center': {'x': coords[i,0], 'y': coords[i,1], 'z': coords[i,2]},
        'radius': 0.5,
        'color': DNAConfig.BASE_COLORS_3D[dna_data[i][3][0]]
    })
    # Second strand
    viewer.addSphere({
        'center': {'x': coords[i,3], 'y': coords[i,4], 'z': coords[i,5]},
        'radius': 0.5,
        'color': DNAConfig.BASE_COLORS_3D[dna_data[i][3][1]]
    })
    # Add connecting cylinder between base pairs
    viewer.addCylinder({
        'start': {'x': coords[i,0], 'y': coords[i,1], 'z': coords[i,2]},
        'end': {'x': coords[i,3], 'y': coords[i,4], 'z': coords[i,5]},
        'radius': 0.2,
        'color': 'gray'
    })

# Add legend
viewer.addLabel("Adenine (A)", {'position': {'x': -10, 'y': 0, 'z': 0}, 'backgroundColor': '#FF0000', 'fontColor': 'white'})
viewer.addLabel("Thymine (T)", {'position': {'x': -10, 'y': -2, 'z': 0}, 'backgroundColor': '#0000FF', 'fontColor': 'white'})
viewer.addLabel("Cytosine (C)", {'position': {'x': -10, 'y': -4, 'z': 0}, 'backgroundColor': '#00FF00', 'fontColor': 'black'})
viewer.addLabel("Guanine (G)", {'position': {'x': -10, 'y': -6, 'z': 0}, 'backgroundColor': '#FFFF00', 'fontColor': 'black'})

viewer.zoomTo()
viewer.update()
# Out:
# <div id="3dmolviewer_17331699886167622"  style="position: relative; width: 1000px; height: 800px;">
#         <p id="3dmolwarning_17331699886167622" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdnjs.cloudflare.com/ajax/libs/3Dmol/2.4.2/3Dmol-min.js');
# }
#
# var viewer_17331699886167622 = null;
# var warn = document.getElementById("3dmolwarning_17331699886167622");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_17331699886167622 = $3Dmol.createViewer(document.getElementById("3dmolviewer_17331699886167622"),{backgroundColor:"white"});
# viewer_17331699886167622.zoomTo();
# viewer_17331699886167622.render();
# });
# </script>
# 2024-12-02 21:06:28,619 - INFO - Loading configuration from config/settings.yaml
# 2024-12-02 21:06:28,621 - INFO - Parsing DNA data from test/large_test_ancestry_data.txt
# <script>
#             $3Dmolpromise.then(function() { //wrap in promise for non-interactive functionality
#                 	viewer_17331699886167622.addSphere({"center": {"x": 4.0, "y": 0.0, "z": 0.0}, "radius": 0.5, "color": "#FF0000"});
# 	viewer_17331699886167622.addSphere({"center": {"x": -4.0, "y": 4.898587196589413e-16, "z": 0.0}, "radius": 0.5, "color": "#00FF00"});
# 	viewer_17331699886167622.addCylinder({"start": {"x": 4.0, "y": 0.0, "z": 0.0}, "end": {"x": -4.0, "y": 4.898587196589413e-16, "z": 0.0}, "radius": 0.2, "color": "gray"});
# 	viewer_17331699886167622.addSphere({"center": {"x": 3.968141434373031, "y": 0.5038388202708702, "z": 0.5051807282154441}, "radius": 0.5, "color": "#FF0000"});
# 	viewer_17331699886167622.addSphere({"center": {"x": -3.968141434373031, "y": -0.5038388202708701, "z": 0.5051807282154441}, "radius": 0.5, "color": "#FFFF00"});
# 	viewer_17331699886167622.addCylinder({"start": {"x": 3.968141434373031, "y": 0.5038388202708702, "z": 0.5051807282154441}, "end": {"x": -3.968141434373031, "y": -0.5038388202708701, "z": 0.5051807282154441}, "radius": 0.2, "color": "gray"});
# 	viewer_17331699886167622.addSphere({"center": {"x": 3.8730732215940287, "y": 0.9996518494812334, "z": 1.0103614564308883}, "radius": 0.5, "color": "#FF0000"});
# 	viewer_17331699886167622.addSphere({"center": {"x": -3.8730732215940287, "y": -0.9996518494812338, "z": 1.0103614564308883}, "radius": 0.5, "color": "#00FF00"});
# 	viewer_17331699886167622.addCylinder({"start": {"x": 3.8730732215940287, "y": 0.9996518494812334, "z": 1.0103614564308883}, "end": {"x": -3.8730732215940287, "y": -0.9996518494812338, "z": 1.0103614564308883}, "radius": 0.2, "color": "gray"});
# 	viewer_17331699886167622.addSphere({"center": {"x": 3.7163097301109222, "y": 1.4795411416661872, "z": 1.5155421846463324}, "radius": 0.5, "color": "#0000FF"});
# 	viewer_17331699886167622.addSphere({"center": {"x": -3.7163097301109227, "y": -1.4795411416661866, "z": 1.5155421846463324}, "radius": 0.5, "color": "#0000FF"});
# 	viewer_17331699886167622.addCylinder({"start": {"x": 3.7163097301109222, "y": 1.4795411416661872, "z": 1.5155421846463324}, "end": {"x": -3.7163097301109227, "y": -1.4795411416661866, "z": 1.5155421846463324}, "radius": 0.2, "color": "gray"});
# 	viewer_17331699886167622.addSphere({"center": {"x": 3.500348089914375, "y": 1.935862404571355, "z": 2.0207229128617765}, "radius": 0.5, "color": "#FFFF00"});
# 	viewer_17331699886167622.addSphere({"center": {"x": -3.500348089914375, "y": -1.9358624045713546, "z": 2.0207229128617765}, "radius": 0.5, "color": "#FF0000"});
# 	viewer_17331699886167622.addCylinder({"start": {"x": 3.500348089914375, "y": 1.935862404571355, "z": 2.0207229128617765}, "end": {"x": -3.500348089914375, "y": -1.9358624045713546, "z": 2.0207229128617765}, "radius": 0.2, "color": "gray"});
# 	viewer_17331699886167622.addSphere({"center": {"x": 3.2286284150479414, "y": 2.3613467677461135, "z": 2.5259036410772207}, "radius": 0.5, "color": "#FF0000"});
# 	viewer_17331699886167622.addSphere({"center": {"x": -3.2286284150479414, "y": -2.3613467677461135, "z": 2.5259036410772207}, "radius": 0.5, "color": "#FF0000"});
# 	viewer_17331699886167622.addCylinder({"start": {"x": 3.2286284150479414, "y": 2.3613467677461135, "z": 2.5259036410772207}, "end": {"x": -3.2286284150479414, "y": -2.3613467677461135, "z": 2.5259036410772207}, "radius": 0.2, "color": "gray"});
# 	viewer_17331699886167622.addSphere({"center": {"x": 2.9054790050585577, "y": 2.749216570436737, "z": 3.031084369292665}, "radius": 0.5, "color": "#0000FF"});
# 	viewer_17331699886167622.addSphere({"center": {"x": -2.9054790050585586, "y": -2.749216570436736, "z": 3.031084369292665}, "radius": 0.5, "color": "#FFFF00"});
# 	viewer_17331699886167622.addCylinder({"start": {"x": 2.9054790050585577, "y": 2.749216570436737, "z": 3.031084369292665}, "end": {"x": -2.9054790050585586, "y": -2.749216570436736, "z": 3.031084369292665}, "radius": 0.2, "color": "gray"});
# 	viewer_17331699886167622.addSphere({"center": {"x": 2.5360473982889546, "y": 3.093293324861356, "z": 3.536265097508109}, "radius": 0.5, "color": "#00FF00"});
# 	viewer_17331699886167622.addSphere({"center": {"x": -2.536047398288954, "y": -3.0932933248613566, "z": 3.536265097508109}, "radius": 0.5, "color": "#FF0000"});
# 	viewer_17331699886167622.addCylinder({"start": {"x": 2.5360473982889546, "y": 3.093293324861356, "z": 3.536265097508109}, "end": {"x": -2.536047398288954, "y": -3.0932933248613566, "z": 3.536265097508109}, "radius": 0.2, "color": "gray"});
# 	viewer_17331699886167622.addSphere({"center": {"x": 2.1262183752836057, "y": 3.3880961350891954, "z": 4.041445825723553}, "radius": 0.5, "color": "#0000FF"});
# 	viewer_17331699886167622.addSphere({"center": {"x": -2.126218375283606, "y": -3.3880961350891954, "z": 4.041445825723553}, "radius": 0.5, "color": "#FFFF00"});
# 	viewer_17331699886167622.addCylinder({"start": {"x": 2.1262183752836057, "y": 3.3880961350891954, "z": 4.041445825723553}, "end": {"x": -2.126218375283606, "y": -3.3880961350891954, "z": 4.041445825723553}, "radius": 0.2, "color": "gray"});
# 	viewer_17331699886167622.addSphere({"center": {"x": 1.6825202184551367, "y": 3.6289290037819257, "z": 4.546626553938998}, "radius": 0.5, "color": "#00FF00"});
# 	viewer_17331699886167622.addSphere({"center": {"x": -1.6825202184551356, "y": -3.628929003781926, "z": 4.546626553938998}, "radius": 0.5, "color": "#FFFF00"});
# 	viewer_17331699886167622.addCylinder({"start": {"x": 1.6825202184551367, "y": 3.6289290037819257, "z": 4.546626553938998}, "end": {"x": -1.6825202184551356, "y": -3.628929003781926, "z": 4.546626553938998}, "radius": 0.2, "color": "gray"});
# 	viewer_17331699886167622.addSphere({"center": {"x": 1.212020721227491, "y": 3.811955636063357, "z": 5.051807282154441}, "radius": 0.5, "color": "#FF0000"});
# 	viewer_17331699886167622.addSphere({"center": {"x": -1.2120207212274907, "y": -3.8119556360633573, "z": 5.051807282154441}, "radius": 0.5, "color": "#00FF00"});
# 	viewer_17331699886167622.addCylinder({"start": {"x": 1.212020721227491, "y": 3.811955636063357, "z": 5.051807282154441}, "end": {"x": -1.2120207212274907, "y": -3.8119556360633573, "z": 5.051807282154441}, "radius": 0.2, "color": "gray"});
# 	viewer_17331699886167622.addSphere({"center": {"x": 0.7222146031556093, "y": 3.9342605489454794, "z": 5.556988010369885}, "radius": 0.5, "color": "#FF0000"});
# 	viewer_17331699886167622.addSphere({"center": {"x": -0.7222146031556098, "y": -3.9342605489454794, "z": 5.556988010369885}, "radius": 0.5, "color": "#FF0000"});
# 	viewer_17331699886167622.addCylinder({"start": {"x": 0.7222146031556093, "y": 3.9342605489454794, "z": 5.556988010369885}, "end": {"x": -0.7222146031556098, "y": -3.9342605489454794, "z": 5.556988010369885}, "radius": 0.2, "color": "gray"});
# 	viewer_17331699886167622.addSphere({"center": {"x": 0.22090412441803267, "y": 3.9938955128815152, "z": 6.06216873858533}, "radius": 0.5, "color": "#FFFF00"});
# 	viewer_17331699886167622.addSphere({"center": {"x": -0.22090412441803492, "y": -3.9938955128815152, "z": 6.06216873858533}, "radius": 0.5, "color": "#FF0000"});
# 	viewer_17331699886167622.addCylinder({"start": {"x": 0.22090412441803267, "y": 3.9938955128815152, "z": 6.06216873858533}, "end": {"x": -0.22090412441803492, "y": -3.9938955128815152, "z": 6.06216873858533}, "radius": 0.2, "color": "gray"});
# 	viewer_17331699886167622.addSphere({"center": {"x": -0.283925198592064, "y": 3.989910585665355, "z": 6.567349466800774}, "radius": 0.5, "color": "#FFFF00"});
# 	viewer_17331699886167622.addSphere({"center": {"x": 0.2839251985920635, "y": -3.989910585665355, "z": 6.567349466800774}, "radius": 0.5, "color": "#00FF00"});
# 	viewer_17331699886167622.addCylinder({"start": {"x": -0.283925198592064, "y": 3.989910585665355, "z": 6.567349466800774}, "end": {"x": 0.2839251985920635, "y": -3.989910585665355, "z": 6.567349466800774}, "radius": 0.2, "color": "gray"});
# 	viewer_17331699886167622.addSphere({"center": {"x": -0.784231796815912, "y": 3.9223692443296163, "z": 7.072530195016218},
